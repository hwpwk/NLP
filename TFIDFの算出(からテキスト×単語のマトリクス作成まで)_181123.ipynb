# %%
import pandas as pd
import numpy as np

# 可視化用のライブラリ
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

import neologdn
import MeCab

import re

from tqdm import tqdm_notebook as tqdm
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas(desc="progress: ")

# %%
df = pd.read_csv('all_text_wakatigaki.csv',encoding='utf-8')
df.head()
# Out:
#    surface     yomi original        type katsuyoukei katsuyougata  \
# 0  neologd  ネオログディー  NEologd  名詞-固有名詞-一般         NaN          NaN
# 1        _        _        _       記号-一般         NaN          NaN
# 2   tagger      タガー   tagger  名詞-固有名詞-一般         NaN          NaN
# 3        .        .        .       記号-一般         NaN          NaN
# 4    parse      パース    Parse  名詞-固有名詞-一般         NaN          NaN
#
#                                                   内容
# 0  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 1  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 2  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 3  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 4  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...

# %% [markdown]
# ## TF値算出

# %%
# 単語名は同一でも品詞名が違う組み合わせがあるので単語名と品詞名を組み合わせた要素を格納した新規カラムを作成する
df['original_type'] = df['original'] + '_' + df['type']
df.head()
# Out:
#    surface     yomi original        type katsuyoukei katsuyougata  \
# 0  neologd  ネオログディー  NEologd  名詞-固有名詞-一般         NaN          NaN
# 1        _        _        _       記号-一般         NaN          NaN
# 2   tagger      タガー   tagger  名詞-固有名詞-一般         NaN          NaN
# 3        .        .        .       記号-一般         NaN          NaN
# 4    parse      パース    Parse  名詞-固有名詞-一般         NaN          NaN
#
#                                                   内容       original_type
# 0  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...  NEologd_名詞-固有名詞-一般
# 1  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             __記号-一般
# 2  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...   tagger_名詞-固有名詞-一般
# 3  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             ._記号-一般
# 4  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...    Parse_名詞-固有名詞-一般

# %%
# 必要カラムのみ抽出
df = df[['yomi', '内容', 'original_type']]
df.head()
# Out:
#       yomi                                                 内容  \
# 0  ネオログディー  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 1        _  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 2      タガー  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 3        .  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
# 4      パース  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...
#
#         original_type
# 0  NEologd_名詞-固有名詞-一般
# 1             __記号-一般
# 2   tagger_名詞-固有名詞-一般
# 3             ._記号-一般
# 4    Parse_名詞-固有名詞-一般

# %%
# [内容]×[original_type]の組み合わせの数をカウント
contents_word_cnt_df = df.groupby(['内容', 'original_type']).count().reset_index()
contents_word_cnt_df = contents_word_cnt_df.rename(columns={'yomi':'count'})
contents_word_cnt_df.head()
# Out:
#                                                   内容       original_type  \
# 0  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             (_記号-一般
# 1  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             )_記号-一般
# 2  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             ._記号-一般
# 3  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...              1_名詞-数
# 4  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...  NEologd_名詞-固有名詞-一般
#
#    count
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
# 文書毎に含まれる単語数をカウント

# [内容]カラムをグループ化しカウント　
# reset_index関数を使い[内容]カラムをindex部分からデータ列部分に戻す
per_sentence_word_cnt = df.groupby('内容')['original_type'].count().reset_index()
per_sentence_word_cnt = per_sentence_word_cnt.rename(columns={'original_type':'word_count'})
per_sentence_word_cnt.head()
# Out:
#                                                   内容  word_count
# 0  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...          26
# 1  まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...          30
# 2     原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される          33
# 3  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...          41

# %%
# [count]と[word_count]を [内容]で紐づけ
contents_merge_df = pd.merge(contents_word_cnt_df, per_sentence_word_cnt, on='内容', how='inner')
contents_merge_df.head(27)
# Out:
#                                                    内容       original_type  \
# 0   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             (_記号-一般
# 1   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             )_記号-一般
# 2   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             ._記号-一般
# 3   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...              1_名詞-数
# 4   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...  NEologd_名詞-固有名詞-一般
# 5   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...    Parse_名詞-固有名詞-一般
# 6   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             __記号-一般
# 7   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...   tagger_名詞-固有名詞-一般
# 8   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...     text_名詞-固有名詞-一般
# 9   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             、_記号-読点
# 10  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         が_助詞-格助詞-一般
# 11  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            する_動詞-自立
# 12  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...           て_助詞-接続助詞
# 13  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         で_助詞-格助詞-一般
# 14  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...           など_助詞-副助詞
# 15  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            の_助詞-連体化
# 16  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            れる_動詞-接尾
# 17  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            単語_名詞-一般
# 18  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            原形_名詞-一般
# 19  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...          各_接頭詞-名詞接続
# 20  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            品詞_名詞-一般
# 21  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         行_名詞-接尾-助数詞
# 22  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...          表示_名詞-サ変接続
# 23  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...          連続_名詞-サ変接続
# 24  まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...       ()_名詞-固有名詞-一般
# 25  まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...            1つ_名詞-一般
# 26  まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...    Parse_名詞-固有名詞-一般
#
#     count  word_count
# 0       1          26
# 1       1          26
# 2       1          26
# 3       1          26
# 4       1          26
# 5       1          26
# 6       1          26
# 7       1          26
# 8       1          26
# 9       1          26
# 10      1          26
# 11      2          26
# 12      1          26
# 13      2          26
# 14      1          26
# 15      1          26
# 16      1          26
# 17      1          26
# 18      1          26
# 19      1          26
# 20      1          26
# 21      1          26
# 22      1          26
# 23      1          26
# 24      1          30
# 25      1          30
# 26      1          30

# %%
# 欠損値があるか確認
contents_merge_df.isnull().any()
# Out:
# 内容               False
# original_type    False
# count            False
# word_count       False
# dtype: bool

# %%
# tf値算出に必要なカラム（分子と分母の値があるカラム）のみ抽出
tmp_tf_df = contents_merge_df[['count', 'word_count']]
tmp_tf_df.head()
# Out:
#    count  word_count
# 0      1          26
# 1      1          26
# 2      1          26
# 3      1          26
# 4      1          26

# %%
# tf値算出
# axis=1をつけないと"occurred at index count"とエラーが発生する（デフォルトがaxis=0のため）
contents_merge_df['tf'] = tmp_tf_df.progress_apply(lambda x: x['count'] / x['word_count'], axis=1)
# Out:
# HBox(children=(IntProgress(value=0, description='progress: ', max=105), HTML(value='')))

# %%
# tf値が紐づいたか確認
contents_merge_df.head()
# Out:
#                                                   内容       original_type  \
# 0  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             (_記号-一般
# 1  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             )_記号-一般
# 2  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             ._記号-一般
# 3  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...              1_名詞-数
# 4  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...  NEologd_名詞-固有名詞-一般
#
#    count  word_count        tf
# 0      1          26  0.038462
# 1      1          26  0.038462
# 2      1          26  0.038462
# 3      1          26  0.038462
# 4      1          26  0.038462

# %% [markdown]
# ## IDF値算出

# %%
# idfの分子（全文書数）
len(contents_word_cnt_df['内容'].value_counts())
# Out:
# 4

# %%
# idfの分母「各単語が出現する文書の数」の算出
# [original_type]×[内容]のクロス集計表を作成

idf_pivot_df = pd.pivot_table(contents_merge_df, index='original_type', columns='内容', aggfunc=len, values='count')
#tf_pivot_df = pd.pivot_table(contents_merge_df, index='original_type', columns='内容', values='count')#aggfuncを指定しないと[count]カラムの数字が入る
idf_pivot_df
# Out:
# 内容                  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表示される  \
# original_type
# ')_記号-一般                                                          NaN
# ('\_記号-一般                                                         NaN
# ()_名詞-固有名詞-一般                                                     NaN
# (_記号-一般                                                           1.0
# )_記号-一般                                                           1.0
# ._記号-一般                                                           1.0
# 1_名詞-数                                                            1.0
# 1つ_名詞-一般                                                          NaN
# NEologd_名詞-固有名詞-一般                                                1.0
# Parse_名詞-固有名詞-一般                                                  1.0
# \_記号-一般                                                           NaN
# __記号-一般                                                           1.0
# n_名詞-固有名詞-組織                                                      NaN
# split_名詞-一般                                                       NaN
# split_名詞-固有名詞-組織                                                  NaN
# t_名詞-固有名詞-組織                                                      NaN
# tagger_名詞-固有名詞-一般                                                 1.0
# text_名詞-固有名詞-一般                                                   1.0
# wakatid_名詞-一般                                                     NaN
# 、_記号-読点                                                           1.0
# 。_記号-句点                                                           NaN
# 「\_記号-一般                                                          NaN
# 「_記号-括弧開                                                          NaN
# 」_記号-括弧閉                                                          NaN
# いる_動詞-非自立                                                         NaN
# が_助詞-接続助詞                                                         NaN
# が_助詞-格助詞-一般                                                       1.0
# する_動詞-自立                                                          1.0
# た_助動詞                                                             NaN
# たい_助動詞                                                            NaN
# ...                                                               ...
# なる_動詞-自立                                                          NaN
# に_助詞-格助詞-一般                                                       NaN
# の_助詞-連体化                                                          1.0
# ので_助詞-接続助詞                                                        NaN
# は_助詞-係助詞                                                          NaN
# まずは_接続詞                                                           NaN
# よって_接続詞                                                           NaN
# れる_動詞-接尾                                                          1.0
# を_助詞-格助詞-一般                                                       NaN
# リスト_名詞-一般                                                         NaN
# 使用_名詞-サ変接続                                                        NaN
# 分かち書き_名詞-一般                                                       NaN
# 区切り_名詞-一般                                                         NaN
# 区切る_動詞-自立                                                         NaN
# 単語_名詞-一般                                                          1.0
# 原形_名詞-一般                                                          1.0
# 各_接頭詞-名詞接続                                                        1.0
# 品詞_名詞-一般                                                          1.0
# 型_名詞-接尾-一般                                                        NaN
# 文字_名詞-一般                                                          NaN
# 文字列_名詞-固有名詞-一般                                                    NaN
# 次に_接続詞                                                            NaN
# 省く_動詞-自立                                                          NaN
# 群_名詞-接尾-一般                                                        NaN
# 行_名詞-接尾-助数詞                                                       1.0
# 表示_名詞-サ変接続                                                        1.0
# 連続_名詞-サ変接続                                                        1.0
# 邪魔_名詞-形容動詞語幹                                                      NaN
# 間_名詞-一般                                                           NaN
# 関数_名詞-一般                                                          NaN
#
# 内容                  まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リスト型にする  \
# original_type
# ')_記号-一般                                                          NaN
# ('\_記号-一般                                                         NaN
# ()_名詞-固有名詞-一般                                                     1.0
# (_記号-一般                                                           NaN
# )_記号-一般                                                           NaN
# ._記号-一般                                                           NaN
# 1_名詞-数                                                            NaN
# 1つ_名詞-一般                                                          1.0
# NEologd_名詞-固有名詞-一般                                                NaN
# Parse_名詞-固有名詞-一般                                                  1.0
# \_記号-一般                                                           1.0
# __記号-一般                                                           NaN
# n_名詞-固有名詞-組織                                                      1.0
# split_名詞-一般                                                       NaN
# split_名詞-固有名詞-組織                                                  NaN
# t_名詞-固有名詞-組織                                                      NaN
# tagger_名詞-固有名詞-一般                                                 NaN
# text_名詞-固有名詞-一般                                                   NaN
# wakatid_名詞-一般                                                     NaN
# 、_記号-読点                                                           1.0
# 。_記号-句点                                                           NaN
# 「\_記号-一般                                                          NaN
# 「_記号-括弧開                                                          1.0
# 」_記号-括弧閉                                                          1.0
# いる_動詞-非自立                                                         1.0
# が_助詞-接続助詞                                                         NaN
# が_助詞-格助詞-一般                                                       NaN
# する_動詞-自立                                                          1.0
# た_助動詞                                                             1.0
# たい_助動詞                                                            NaN
# ...                                                               ...
# なる_動詞-自立                                                          1.0
# に_助詞-格助詞-一般                                                       1.0
# の_助詞-連体化                                                          1.0
# ので_助詞-接続助詞                                                        1.0
# は_助詞-係助詞                                                          1.0
# まずは_接続詞                                                           1.0
# よって_接続詞                                                           NaN
# れる_動詞-接尾                                                          NaN
# を_助詞-格助詞-一般                                                       NaN
# リスト_名詞-一般                                                         1.0
# 使用_名詞-サ変接続                                                        NaN
# 分かち書き_名詞-一般                                                       1.0
# 区切り_名詞-一般                                                         NaN
# 区切る_動詞-自立                                                         1.0
# 単語_名詞-一般                                                          1.0
# 原形_名詞-一般                                                          NaN
# 各_接頭詞-名詞接続                                                        NaN
# 品詞_名詞-一般                                                          NaN
# 型_名詞-接尾-一般                                                        1.0
# 文字_名詞-一般                                                          NaN
# 文字列_名詞-固有名詞-一般                                                    1.0
# 次に_接続詞                                                            NaN
# 省く_動詞-自立                                                          NaN
# 群_名詞-接尾-一般                                                        1.0
# 行_名詞-接尾-助数詞                                                       NaN
# 表示_名詞-サ変接続                                                        NaN
# 連続_名詞-サ変接続                                                        NaN
# 邪魔_名詞-形容動詞語幹                                                      NaN
# 間_名詞-一般                                                           NaN
# 関数_名詞-一般                                                          NaN
#
# 内容                  原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される  \
# original_type
# ')_記号-一般                                                       NaN
# ('\_記号-一般                                                      NaN
# ()_名詞-固有名詞-一般                                                  NaN
# (_記号-一般                                                        NaN
# )_記号-一般                                                        NaN
# ._記号-一般                                                        NaN
# 1_名詞-数                                                         NaN
# 1つ_名詞-一般                                                       NaN
# NEologd_名詞-固有名詞-一般                                             NaN
# Parse_名詞-固有名詞-一般                                               NaN
# \_記号-一般                                                        1.0
# __記号-一般                                                        NaN
# n_名詞-固有名詞-組織                                                   1.0
# split_名詞-一般                                                    NaN
# split_名詞-固有名詞-組織                                               NaN
# t_名詞-固有名詞-組織                                                   1.0
# tagger_名詞-固有名詞-一般                                              NaN
# text_名詞-固有名詞-一般                                                NaN
# wakatid_名詞-一般                                                  NaN
# 、_記号-読点                                                        1.0
# 。_記号-句点                                                        NaN
# 「\_記号-一般                                                       NaN
# 「_記号-括弧開                                                       1.0
# 」_記号-括弧閉                                                       1.0
# いる_動詞-非自立                                                      NaN
# が_助詞-接続助詞                                                      NaN
# が_助詞-格助詞-一般                                                    1.0
# する_動詞-自立                                                       1.0
# た_助動詞                                                          1.0
# たい_助動詞                                                         NaN
# ...                                                            ...
# なる_動詞-自立                                                       NaN
# に_助詞-格助詞-一般                                                    1.0
# の_助詞-連体化                                                       1.0
# ので_助詞-接続助詞                                                     NaN
# は_助詞-係助詞                                                       1.0
# まずは_接続詞                                                        NaN
# よって_接続詞                                                        NaN
# れる_動詞-接尾                                                       1.0
# を_助詞-格助詞-一般                                                    NaN
# リスト_名詞-一般                                                      NaN
# 使用_名詞-サ変接続                                                     NaN
# 分かち書き_名詞-一般                                                    1.0
# 区切り_名詞-一般                                                      1.0
# 区切る_動詞-自立                                                      NaN
# 単語_名詞-一般                                                       1.0
# 原形_名詞-一般                                                       1.0
# 各_接頭詞-名詞接続                                                     NaN
# 品詞_名詞-一般                                                       1.0
# 型_名詞-接尾-一般                                                     NaN
# 文字_名詞-一般                                                       NaN
# 文字列_名詞-固有名詞-一般                                                 NaN
# 次に_接続詞                                                         NaN
# 省く_動詞-自立                                                       NaN
# 群_名詞-接尾-一般                                                     NaN
# 行_名詞-接尾-助数詞                                                    NaN
# 表示_名詞-サ変接続                                                     1.0
# 連続_名詞-サ変接続                                                     NaN
# 邪魔_名詞-形容動詞語幹                                                   NaN
# 間_名詞-一般                                                        1.0
# 関数_名詞-一般                                                       NaN
#
# 内容                  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_textは文字列型ではなくリスト型のためsplit関数を使用できない
# original_type
# ')_記号-一般                                                          1.0
# ('\_記号-一般                                                         1.0
# ()_名詞-固有名詞-一般                                                     NaN
# (_記号-一般                                                           NaN
# )_記号-一般                                                           NaN
# ._記号-一般                                                           NaN
# 1_名詞-数                                                            NaN
# 1つ_名詞-一般                                                          NaN
# NEologd_名詞-固有名詞-一般                                                NaN
# Parse_名詞-固有名詞-一般                                                  NaN
# \_記号-一般                                                           NaN
# __記号-一般                                                           1.0
# n_名詞-固有名詞-組織                                                      NaN
# split_名詞-一般                                                       1.0
# split_名詞-固有名詞-組織                                                  1.0
# t_名詞-固有名詞-組織                                                      1.0
# tagger_名詞-固有名詞-一般                                                 NaN
# text_名詞-固有名詞-一般                                                   1.0
# wakatid_名詞-一般                                                     1.0
# 、_記号-読点                                                           1.0
# 。_記号-句点                                                           1.0
# 「\_記号-一般                                                          1.0
# 「_記号-括弧開                                                          NaN
# 」_記号-括弧閉                                                          1.0
# いる_動詞-非自立                                                         NaN
# が_助詞-接続助詞                                                         1.0
# が_助詞-格助詞-一般                                                       NaN
# する_動詞-自立                                                          1.0
# た_助動詞                                                             NaN
# たい_助動詞                                                            1.0
# ...                                                               ...
# なる_動詞-自立                                                          NaN
# に_助詞-格助詞-一般                                                       NaN
# の_助詞-連体化                                                          1.0
# ので_助詞-接続助詞                                                        NaN
# は_助詞-係助詞                                                          1.0
# まずは_接続詞                                                           NaN
# よって_接続詞                                                           1.0
# れる_動詞-接尾                                                          NaN
# を_助詞-格助詞-一般                                                       1.0
# リスト_名詞-一般                                                         1.0
# 使用_名詞-サ変接続                                                        1.0
# 分かち書き_名詞-一般                                                       NaN
# 区切り_名詞-一般                                                         NaN
# 区切る_動詞-自立                                                         NaN
# 単語_名詞-一般                                                          NaN
# 原形_名詞-一般                                                          NaN
# 各_接頭詞-名詞接続                                                        NaN
# 品詞_名詞-一般                                                          NaN
# 型_名詞-接尾-一般                                                        1.0
# 文字_名詞-一般                                                          1.0
# 文字列_名詞-固有名詞-一般                                                    1.0
# 次に_接続詞                                                            1.0
# 省く_動詞-自立                                                          1.0
# 群_名詞-接尾-一般                                                        NaN
# 行_名詞-接尾-助数詞                                                       NaN
# 表示_名詞-サ変接続                                                        NaN
# 連続_名詞-サ変接続                                                        NaN
# 邪魔_名詞-形容動詞語幹                                                      1.0
# 間_名詞-一般                                                           NaN
# 関数_名詞-一般                                                          1.0
#
# [68 rows x 4 columns]

# %%
idf_pivot_df1 = idf_pivot_df > 0
idf_pivot_df1# 1以上ならTrue、1未満ならFalse
# Out:
# 内容                  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表示される  \
# original_type
# ')_記号-一般                                                        False
# ('\_記号-一般                                                       False
# ()_名詞-固有名詞-一般                                                   False
# (_記号-一般                                                          True
# )_記号-一般                                                          True
# ._記号-一般                                                          True
# 1_名詞-数                                                           True
# 1つ_名詞-一般                                                        False
# NEologd_名詞-固有名詞-一般                                               True
# Parse_名詞-固有名詞-一般                                                 True
# \_記号-一般                                                         False
# __記号-一般                                                          True
# n_名詞-固有名詞-組織                                                    False
# split_名詞-一般                                                     False
# split_名詞-固有名詞-組織                                                False
# t_名詞-固有名詞-組織                                                    False
# tagger_名詞-固有名詞-一般                                                True
# text_名詞-固有名詞-一般                                                  True
# wakatid_名詞-一般                                                   False
# 、_記号-読点                                                          True
# 。_記号-句点                                                         False
# 「\_記号-一般                                                        False
# 「_記号-括弧開                                                        False
# 」_記号-括弧閉                                                        False
# いる_動詞-非自立                                                       False
# が_助詞-接続助詞                                                       False
# が_助詞-格助詞-一般                                                      True
# する_動詞-自立                                                         True
# た_助動詞                                                           False
# たい_助動詞                                                          False
# ...                                                               ...
# なる_動詞-自立                                                        False
# に_助詞-格助詞-一般                                                     False
# の_助詞-連体化                                                         True
# ので_助詞-接続助詞                                                      False
# は_助詞-係助詞                                                        False
# まずは_接続詞                                                         False
# よって_接続詞                                                         False
# れる_動詞-接尾                                                         True
# を_助詞-格助詞-一般                                                     False
# リスト_名詞-一般                                                       False
# 使用_名詞-サ変接続                                                      False
# 分かち書き_名詞-一般                                                     False
# 区切り_名詞-一般                                                       False
# 区切る_動詞-自立                                                       False
# 単語_名詞-一般                                                         True
# 原形_名詞-一般                                                         True
# 各_接頭詞-名詞接続                                                       True
# 品詞_名詞-一般                                                         True
# 型_名詞-接尾-一般                                                      False
# 文字_名詞-一般                                                        False
# 文字列_名詞-固有名詞-一般                                                  False
# 次に_接続詞                                                          False
# 省く_動詞-自立                                                        False
# 群_名詞-接尾-一般                                                      False
# 行_名詞-接尾-助数詞                                                      True
# 表示_名詞-サ変接続                                                       True
# 連続_名詞-サ変接続                                                       True
# 邪魔_名詞-形容動詞語幹                                                    False
# 間_名詞-一般                                                         False
# 関数_名詞-一般                                                        False
#
# 内容                  まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リスト型にする  \
# original_type
# ')_記号-一般                                                        False
# ('\_記号-一般                                                       False
# ()_名詞-固有名詞-一般                                                    True
# (_記号-一般                                                         False
# )_記号-一般                                                         False
# ._記号-一般                                                         False
# 1_名詞-数                                                          False
# 1つ_名詞-一般                                                         True
# NEologd_名詞-固有名詞-一般                                              False
# Parse_名詞-固有名詞-一般                                                 True
# \_記号-一般                                                          True
# __記号-一般                                                         False
# n_名詞-固有名詞-組織                                                     True
# split_名詞-一般                                                     False
# split_名詞-固有名詞-組織                                                False
# t_名詞-固有名詞-組織                                                    False
# tagger_名詞-固有名詞-一般                                               False
# text_名詞-固有名詞-一般                                                 False
# wakatid_名詞-一般                                                   False
# 、_記号-読点                                                          True
# 。_記号-句点                                                         False
# 「\_記号-一般                                                        False
# 「_記号-括弧開                                                         True
# 」_記号-括弧閉                                                         True
# いる_動詞-非自立                                                        True
# が_助詞-接続助詞                                                       False
# が_助詞-格助詞-一般                                                     False
# する_動詞-自立                                                         True
# た_助動詞                                                            True
# たい_助動詞                                                          False
# ...                                                               ...
# なる_動詞-自立                                                         True
# に_助詞-格助詞-一般                                                      True
# の_助詞-連体化                                                         True
# ので_助詞-接続助詞                                                       True
# は_助詞-係助詞                                                         True
# まずは_接続詞                                                          True
# よって_接続詞                                                         False
# れる_動詞-接尾                                                        False
# を_助詞-格助詞-一般                                                     False
# リスト_名詞-一般                                                        True
# 使用_名詞-サ変接続                                                      False
# 分かち書き_名詞-一般                                                      True
# 区切り_名詞-一般                                                       False
# 区切る_動詞-自立                                                        True
# 単語_名詞-一般                                                         True
# 原形_名詞-一般                                                        False
# 各_接頭詞-名詞接続                                                      False
# 品詞_名詞-一般                                                        False
# 型_名詞-接尾-一般                                                       True
# 文字_名詞-一般                                                        False
# 文字列_名詞-固有名詞-一般                                                   True
# 次に_接続詞                                                          False
# 省く_動詞-自立                                                        False
# 群_名詞-接尾-一般                                                       True
# 行_名詞-接尾-助数詞                                                     False
# 表示_名詞-サ変接続                                                      False
# 連続_名詞-サ変接続                                                      False
# 邪魔_名詞-形容動詞語幹                                                    False
# 間_名詞-一般                                                         False
# 関数_名詞-一般                                                        False
#
# 内容                  原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される  \
# original_type
# ')_記号-一般                                                     False
# ('\_記号-一般                                                    False
# ()_名詞-固有名詞-一般                                                False
# (_記号-一般                                                      False
# )_記号-一般                                                      False
# ._記号-一般                                                      False
# 1_名詞-数                                                       False
# 1つ_名詞-一般                                                     False
# NEologd_名詞-固有名詞-一般                                           False
# Parse_名詞-固有名詞-一般                                             False
# \_記号-一般                                                       True
# __記号-一般                                                      False
# n_名詞-固有名詞-組織                                                  True
# split_名詞-一般                                                  False
# split_名詞-固有名詞-組織                                             False
# t_名詞-固有名詞-組織                                                  True
# tagger_名詞-固有名詞-一般                                            False
# text_名詞-固有名詞-一般                                              False
# wakatid_名詞-一般                                                False
# 、_記号-読点                                                       True
# 。_記号-句点                                                      False
# 「\_記号-一般                                                     False
# 「_記号-括弧開                                                      True
# 」_記号-括弧閉                                                      True
# いる_動詞-非自立                                                    False
# が_助詞-接続助詞                                                    False
# が_助詞-格助詞-一般                                                   True
# する_動詞-自立                                                      True
# た_助動詞                                                         True
# たい_助動詞                                                       False
# ...                                                            ...
# なる_動詞-自立                                                     False
# に_助詞-格助詞-一般                                                   True
# の_助詞-連体化                                                      True
# ので_助詞-接続助詞                                                   False
# は_助詞-係助詞                                                      True
# まずは_接続詞                                                      False
# よって_接続詞                                                      False
# れる_動詞-接尾                                                      True
# を_助詞-格助詞-一般                                                  False
# リスト_名詞-一般                                                    False
# 使用_名詞-サ変接続                                                   False
# 分かち書き_名詞-一般                                                   True
# 区切り_名詞-一般                                                     True
# 区切る_動詞-自立                                                    False
# 単語_名詞-一般                                                      True
# 原形_名詞-一般                                                      True
# 各_接頭詞-名詞接続                                                   False
# 品詞_名詞-一般                                                      True
# 型_名詞-接尾-一般                                                   False
# 文字_名詞-一般                                                     False
# 文字列_名詞-固有名詞-一般                                               False
# 次に_接続詞                                                       False
# 省く_動詞-自立                                                     False
# 群_名詞-接尾-一般                                                   False
# 行_名詞-接尾-助数詞                                                  False
# 表示_名詞-サ変接続                                                    True
# 連続_名詞-サ変接続                                                   False
# 邪魔_名詞-形容動詞語幹                                                 False
# 間_名詞-一般                                                       True
# 関数_名詞-一般                                                     False
#
# 内容                  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_textは文字列型ではなくリスト型のためsplit関数を使用できない
# original_type
# ')_記号-一般                                                         True
# ('\_記号-一般                                                        True
# ()_名詞-固有名詞-一般                                                   False
# (_記号-一般                                                         False
# )_記号-一般                                                         False
# ._記号-一般                                                         False
# 1_名詞-数                                                          False
# 1つ_名詞-一般                                                        False
# NEologd_名詞-固有名詞-一般                                              False
# Parse_名詞-固有名詞-一般                                                False
# \_記号-一般                                                         False
# __記号-一般                                                          True
# n_名詞-固有名詞-組織                                                    False
# split_名詞-一般                                                      True
# split_名詞-固有名詞-組織                                                 True
# t_名詞-固有名詞-組織                                                     True
# tagger_名詞-固有名詞-一般                                               False
# text_名詞-固有名詞-一般                                                  True
# wakatid_名詞-一般                                                    True
# 、_記号-読点                                                          True
# 。_記号-句点                                                          True
# 「\_記号-一般                                                         True
# 「_記号-括弧開                                                        False
# 」_記号-括弧閉                                                         True
# いる_動詞-非自立                                                       False
# が_助詞-接続助詞                                                        True
# が_助詞-格助詞-一般                                                     False
# する_動詞-自立                                                         True
# た_助動詞                                                           False
# たい_助動詞                                                           True
# ...                                                               ...
# なる_動詞-自立                                                        False
# に_助詞-格助詞-一般                                                     False
# の_助詞-連体化                                                         True
# ので_助詞-接続助詞                                                      False
# は_助詞-係助詞                                                         True
# まずは_接続詞                                                         False
# よって_接続詞                                                          True
# れる_動詞-接尾                                                        False
# を_助詞-格助詞-一般                                                      True
# リスト_名詞-一般                                                        True
# 使用_名詞-サ変接続                                                       True
# 分かち書き_名詞-一般                                                     False
# 区切り_名詞-一般                                                       False
# 区切る_動詞-自立                                                       False
# 単語_名詞-一般                                                        False
# 原形_名詞-一般                                                        False
# 各_接頭詞-名詞接続                                                      False
# 品詞_名詞-一般                                                        False
# 型_名詞-接尾-一般                                                       True
# 文字_名詞-一般                                                         True
# 文字列_名詞-固有名詞-一般                                                   True
# 次に_接続詞                                                           True
# 省く_動詞-自立                                                         True
# 群_名詞-接尾-一般                                                      False
# 行_名詞-接尾-助数詞                                                     False
# 表示_名詞-サ変接続                                                      False
# 連続_名詞-サ変接続                                                      False
# 邪魔_名詞-形容動詞語幹                                                     True
# 間_名詞-一般                                                         False
# 関数_名詞-一般                                                         True
#
# [68 rows x 4 columns]

# %%
# True＝１なのでTureの数を行毎に合計
# それを格納するカラム[word_include_text_count]を追加
# この値がidfの分母となる
idf_pivot_df1['word_include_text_count'] = idf_pivot_df1.sum(axis=1)
idf_pivot_df1
# Out:
# 内容                  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表示される  \
# original_type
# ')_記号-一般                                                        False
# ('\_記号-一般                                                       False
# ()_名詞-固有名詞-一般                                                   False
# (_記号-一般                                                          True
# )_記号-一般                                                          True
# ._記号-一般                                                          True
# 1_名詞-数                                                           True
# 1つ_名詞-一般                                                        False
# NEologd_名詞-固有名詞-一般                                               True
# Parse_名詞-固有名詞-一般                                                 True
# \_記号-一般                                                         False
# __記号-一般                                                          True
# n_名詞-固有名詞-組織                                                    False
# split_名詞-一般                                                     False
# split_名詞-固有名詞-組織                                                False
# t_名詞-固有名詞-組織                                                    False
# tagger_名詞-固有名詞-一般                                                True
# text_名詞-固有名詞-一般                                                  True
# wakatid_名詞-一般                                                   False
# 、_記号-読点                                                          True
# 。_記号-句点                                                         False
# 「\_記号-一般                                                        False
# 「_記号-括弧開                                                        False
# 」_記号-括弧閉                                                        False
# いる_動詞-非自立                                                       False
# が_助詞-接続助詞                                                       False
# が_助詞-格助詞-一般                                                      True
# する_動詞-自立                                                         True
# た_助動詞                                                           False
# たい_助動詞                                                          False
# ...                                                               ...
# なる_動詞-自立                                                        False
# に_助詞-格助詞-一般                                                     False
# の_助詞-連体化                                                         True
# ので_助詞-接続助詞                                                      False
# は_助詞-係助詞                                                        False
# まずは_接続詞                                                         False
# よって_接続詞                                                         False
# れる_動詞-接尾                                                         True
# を_助詞-格助詞-一般                                                     False
# リスト_名詞-一般                                                       False
# 使用_名詞-サ変接続                                                      False
# 分かち書き_名詞-一般                                                     False
# 区切り_名詞-一般                                                       False
# 区切る_動詞-自立                                                       False
# 単語_名詞-一般                                                         True
# 原形_名詞-一般                                                         True
# 各_接頭詞-名詞接続                                                       True
# 品詞_名詞-一般                                                         True
# 型_名詞-接尾-一般                                                      False
# 文字_名詞-一般                                                        False
# 文字列_名詞-固有名詞-一般                                                  False
# 次に_接続詞                                                          False
# 省く_動詞-自立                                                        False
# 群_名詞-接尾-一般                                                      False
# 行_名詞-接尾-助数詞                                                      True
# 表示_名詞-サ変接続                                                       True
# 連続_名詞-サ変接続                                                       True
# 邪魔_名詞-形容動詞語幹                                                    False
# 間_名詞-一般                                                         False
# 関数_名詞-一般                                                        False
#
# 内容                  まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リスト型にする  \
# original_type
# ')_記号-一般                                                        False
# ('\_記号-一般                                                       False
# ()_名詞-固有名詞-一般                                                    True
# (_記号-一般                                                         False
# )_記号-一般                                                         False
# ._記号-一般                                                         False
# 1_名詞-数                                                          False
# 1つ_名詞-一般                                                         True
# NEologd_名詞-固有名詞-一般                                              False
# Parse_名詞-固有名詞-一般                                                 True
# \_記号-一般                                                          True
# __記号-一般                                                         False
# n_名詞-固有名詞-組織                                                     True
# split_名詞-一般                                                     False
# split_名詞-固有名詞-組織                                                False
# t_名詞-固有名詞-組織                                                    False
# tagger_名詞-固有名詞-一般                                               False
# text_名詞-固有名詞-一般                                                 False
# wakatid_名詞-一般                                                   False
# 、_記号-読点                                                          True
# 。_記号-句点                                                         False
# 「\_記号-一般                                                        False
# 「_記号-括弧開                                                         True
# 」_記号-括弧閉                                                         True
# いる_動詞-非自立                                                        True
# が_助詞-接続助詞                                                       False
# が_助詞-格助詞-一般                                                     False
# する_動詞-自立                                                         True
# た_助動詞                                                            True
# たい_助動詞                                                          False
# ...                                                               ...
# なる_動詞-自立                                                         True
# に_助詞-格助詞-一般                                                      True
# の_助詞-連体化                                                         True
# ので_助詞-接続助詞                                                       True
# は_助詞-係助詞                                                         True
# まずは_接続詞                                                          True
# よって_接続詞                                                         False
# れる_動詞-接尾                                                        False
# を_助詞-格助詞-一般                                                     False
# リスト_名詞-一般                                                        True
# 使用_名詞-サ変接続                                                      False
# 分かち書き_名詞-一般                                                      True
# 区切り_名詞-一般                                                       False
# 区切る_動詞-自立                                                        True
# 単語_名詞-一般                                                         True
# 原形_名詞-一般                                                        False
# 各_接頭詞-名詞接続                                                      False
# 品詞_名詞-一般                                                        False
# 型_名詞-接尾-一般                                                       True
# 文字_名詞-一般                                                        False
# 文字列_名詞-固有名詞-一般                                                   True
# 次に_接続詞                                                          False
# 省く_動詞-自立                                                        False
# 群_名詞-接尾-一般                                                       True
# 行_名詞-接尾-助数詞                                                     False
# 表示_名詞-サ変接続                                                      False
# 連続_名詞-サ変接続                                                      False
# 邪魔_名詞-形容動詞語幹                                                    False
# 間_名詞-一般                                                         False
# 関数_名詞-一般                                                        False
#
# 内容                  原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される  \
# original_type
# ')_記号-一般                                                     False
# ('\_記号-一般                                                    False
# ()_名詞-固有名詞-一般                                                False
# (_記号-一般                                                      False
# )_記号-一般                                                      False
# ._記号-一般                                                      False
# 1_名詞-数                                                       False
# 1つ_名詞-一般                                                     False
# NEologd_名詞-固有名詞-一般                                           False
# Parse_名詞-固有名詞-一般                                             False
# \_記号-一般                                                       True
# __記号-一般                                                      False
# n_名詞-固有名詞-組織                                                  True
# split_名詞-一般                                                  False
# split_名詞-固有名詞-組織                                             False
# t_名詞-固有名詞-組織                                                  True
# tagger_名詞-固有名詞-一般                                            False
# text_名詞-固有名詞-一般                                              False
# wakatid_名詞-一般                                                False
# 、_記号-読点                                                       True
# 。_記号-句点                                                      False
# 「\_記号-一般                                                     False
# 「_記号-括弧開                                                      True
# 」_記号-括弧閉                                                      True
# いる_動詞-非自立                                                    False
# が_助詞-接続助詞                                                    False
# が_助詞-格助詞-一般                                                   True
# する_動詞-自立                                                      True
# た_助動詞                                                         True
# たい_助動詞                                                       False
# ...                                                            ...
# なる_動詞-自立                                                     False
# に_助詞-格助詞-一般                                                   True
# の_助詞-連体化                                                      True
# ので_助詞-接続助詞                                                   False
# は_助詞-係助詞                                                      True
# まずは_接続詞                                                      False
# よって_接続詞                                                      False
# れる_動詞-接尾                                                      True
# を_助詞-格助詞-一般                                                  False
# リスト_名詞-一般                                                    False
# 使用_名詞-サ変接続                                                   False
# 分かち書き_名詞-一般                                                   True
# 区切り_名詞-一般                                                     True
# 区切る_動詞-自立                                                    False
# 単語_名詞-一般                                                      True
# 原形_名詞-一般                                                      True
# 各_接頭詞-名詞接続                                                   False
# 品詞_名詞-一般                                                      True
# 型_名詞-接尾-一般                                                   False
# 文字_名詞-一般                                                     False
# 文字列_名詞-固有名詞-一般                                               False
# 次に_接続詞                                                       False
# 省く_動詞-自立                                                     False
# 群_名詞-接尾-一般                                                   False
# 行_名詞-接尾-助数詞                                                  False
# 表示_名詞-サ変接続                                                    True
# 連続_名詞-サ変接続                                                   False
# 邪魔_名詞-形容動詞語幹                                                 False
# 間_名詞-一般                                                       True
# 関数_名詞-一般                                                     False
#
# 内容                  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_textは文字列型ではなくリスト型のためsplit関数を使用できない  \
# original_type
# ')_記号-一般                                                         True
# ('\_記号-一般                                                        True
# ()_名詞-固有名詞-一般                                                   False
# (_記号-一般                                                         False
# )_記号-一般                                                         False
# ._記号-一般                                                         False
# 1_名詞-数                                                          False
# 1つ_名詞-一般                                                        False
# NEologd_名詞-固有名詞-一般                                              False
# Parse_名詞-固有名詞-一般                                                False
# \_記号-一般                                                         False
# __記号-一般                                                          True
# n_名詞-固有名詞-組織                                                    False
# split_名詞-一般                                                      True
# split_名詞-固有名詞-組織                                                 True
# t_名詞-固有名詞-組織                                                     True
# tagger_名詞-固有名詞-一般                                               False
# text_名詞-固有名詞-一般                                                  True
# wakatid_名詞-一般                                                    True
# 、_記号-読点                                                          True
# 。_記号-句点                                                          True
# 「\_記号-一般                                                         True
# 「_記号-括弧開                                                        False
# 」_記号-括弧閉                                                         True
# いる_動詞-非自立                                                       False
# が_助詞-接続助詞                                                        True
# が_助詞-格助詞-一般                                                     False
# する_動詞-自立                                                         True
# た_助動詞                                                           False
# たい_助動詞                                                           True
# ...                                                               ...
# なる_動詞-自立                                                        False
# に_助詞-格助詞-一般                                                     False
# の_助詞-連体化                                                         True
# ので_助詞-接続助詞                                                      False
# は_助詞-係助詞                                                         True
# まずは_接続詞                                                         False
# よって_接続詞                                                          True
# れる_動詞-接尾                                                        False
# を_助詞-格助詞-一般                                                      True
# リスト_名詞-一般                                                        True
# 使用_名詞-サ変接続                                                       True
# 分かち書き_名詞-一般                                                     False
# 区切り_名詞-一般                                                       False
# 区切る_動詞-自立                                                       False
# 単語_名詞-一般                                                        False
# 原形_名詞-一般                                                        False
# 各_接頭詞-名詞接続                                                      False
# 品詞_名詞-一般                                                        False
# 型_名詞-接尾-一般                                                       True
# 文字_名詞-一般                                                         True
# 文字列_名詞-固有名詞-一般                                                   True
# 次に_接続詞                                                           True
# 省く_動詞-自立                                                         True
# 群_名詞-接尾-一般                                                      False
# 行_名詞-接尾-助数詞                                                     False
# 表示_名詞-サ変接続                                                      False
# 連続_名詞-サ変接続                                                      False
# 邪魔_名詞-形容動詞語幹                                                     True
# 間_名詞-一般                                                         False
# 関数_名詞-一般                                                         True
#
# 内容                  word_include_text_count
# original_type
# ')_記号-一般                                  1
# ('\_記号-一般                                 1
# ()_名詞-固有名詞-一般                             1
# (_記号-一般                                   1
# )_記号-一般                                   1
# ._記号-一般                                   1
# 1_名詞-数                                    1
# 1つ_名詞-一般                                  1
# NEologd_名詞-固有名詞-一般                        1
# Parse_名詞-固有名詞-一般                          2
# \_記号-一般                                   2
# __記号-一般                                   2
# n_名詞-固有名詞-組織                              2
# split_名詞-一般                               1
# split_名詞-固有名詞-組織                          1
# t_名詞-固有名詞-組織                              2
# tagger_名詞-固有名詞-一般                         1
# text_名詞-固有名詞-一般                           2
# wakatid_名詞-一般                             1
# 、_記号-読点                                   4
# 。_記号-句点                                   1
# 「\_記号-一般                                  1
# 「_記号-括弧開                                  2
# 」_記号-括弧閉                                  3
# いる_動詞-非自立                                 1
# が_助詞-接続助詞                                 1
# が_助詞-格助詞-一般                               2
# する_動詞-自立                                  4
# た_助動詞                                     2
# たい_助動詞                                    1
# ...                                     ...
# なる_動詞-自立                                  1
# に_助詞-格助詞-一般                               2
# の_助詞-連体化                                  4
# ので_助詞-接続助詞                                1
# は_助詞-係助詞                                  3
# まずは_接続詞                                   1
# よって_接続詞                                   1
# れる_動詞-接尾                                  2
# を_助詞-格助詞-一般                               1
# リスト_名詞-一般                                 2
# 使用_名詞-サ変接続                                1
# 分かち書き_名詞-一般                               2
# 区切り_名詞-一般                                 1
# 区切る_動詞-自立                                 1
# 単語_名詞-一般                                  3
# 原形_名詞-一般                                  2
# 各_接頭詞-名詞接続                                1
# 品詞_名詞-一般                                  2
# 型_名詞-接尾-一般                                2
# 文字_名詞-一般                                  1
# 文字列_名詞-固有名詞-一般                            2
# 次に_接続詞                                    1
# 省く_動詞-自立                                  1
# 群_名詞-接尾-一般                                1
# 行_名詞-接尾-助数詞                               1
# 表示_名詞-サ変接続                                2
# 連続_名詞-サ変接続                                1
# 邪魔_名詞-形容動詞語幹                              1
# 間_名詞-一般                                   1
# 関数_名詞-一般                                  1
#
# [68 rows x 5 columns]

# %%
# 必要なカラム(新規作成カラム、マージするときのキーのカラム）のみ抽出
idf_pivot_df2 = idf_pivot_df1.reset_index()[['original_type', 'word_include_text_count']]
idf_pivot_df2
# Out:
# 内容       original_type  word_include_text_count
# 0             ')_記号-一般                        1
# 1            ('\_記号-一般                        1
# 2        ()_名詞-固有名詞-一般                        1
# 3              (_記号-一般                        1
# 4              )_記号-一般                        1
# 5              ._記号-一般                        1
# 6               1_名詞-数                        1
# 7             1つ_名詞-一般                        1
# 8   NEologd_名詞-固有名詞-一般                        1
# 9     Parse_名詞-固有名詞-一般                        2
# 10             \_記号-一般                        2
# 11             __記号-一般                        2
# 12        n_名詞-固有名詞-組織                        2
# 13         split_名詞-一般                        1
# 14    split_名詞-固有名詞-組織                        1
# 15        t_名詞-固有名詞-組織                        2
# 16   tagger_名詞-固有名詞-一般                        1
# 17     text_名詞-固有名詞-一般                        2
# 18       wakatid_名詞-一般                        1
# 19             、_記号-読点                        4
# 20             。_記号-句点                        1
# 21            「\_記号-一般                        1
# 22            「_記号-括弧開                        2
# 23            」_記号-括弧閉                        3
# 24           いる_動詞-非自立                        1
# 25           が_助詞-接続助詞                        1
# 26         が_助詞-格助詞-一般                        2
# 27            する_動詞-自立                        4
# 28               た_助動詞                        2
# 29              たい_助動詞                        1
# ..                 ...                      ...
# 38            なる_動詞-自立                        1
# 39         に_助詞-格助詞-一般                        2
# 40            の_助詞-連体化                        4
# 41          ので_助詞-接続助詞                        1
# 42            は_助詞-係助詞                        3
# 43             まずは_接続詞                        1
# 44             よって_接続詞                        1
# 45            れる_動詞-接尾                        2
# 46         を_助詞-格助詞-一般                        1
# 47           リスト_名詞-一般                        2
# 48          使用_名詞-サ変接続                        1
# 49         分かち書き_名詞-一般                        2
# 50           区切り_名詞-一般                        1
# 51           区切る_動詞-自立                        1
# 52            単語_名詞-一般                        3
# 53            原形_名詞-一般                        2
# 54          各_接頭詞-名詞接続                        1
# 55            品詞_名詞-一般                        2
# 56          型_名詞-接尾-一般                        2
# 57            文字_名詞-一般                        1
# 58      文字列_名詞-固有名詞-一般                        2
# 59              次に_接続詞                        1
# 60            省く_動詞-自立                        1
# 61          群_名詞-接尾-一般                        1
# 62         行_名詞-接尾-助数詞                        1
# 63          表示_名詞-サ変接続                        2
# 64          連続_名詞-サ変接続                        1
# 65        邪魔_名詞-形容動詞語幹                        1
# 66             間_名詞-一般                        1
# 67            関数_名詞-一般                        1
#
# [68 rows x 2 columns]

# %%
# 新規に作成した「各単語が出現する文書の数」カラムを[original_type]をキーにして連結
idf_merge_df = pd.merge(contents_merge_df, idf_pivot_df2, on='original_type', how='inner')
idf_merge_df
# Out:
#                                                     内容       original_type  \
# 0    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             (_記号-一般
# 1    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             )_記号-一般
# 2    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             ._記号-一般
# 3    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...              1_名詞-数
# 4    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...  NEologd_名詞-固有名詞-一般
# 5    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...    Parse_名詞-固有名詞-一般
# 6    まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...    Parse_名詞-固有名詞-一般
# 7    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             __記号-一般
# 8    次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             __記号-一般
# 9    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...   tagger_名詞-固有名詞-一般
# 10   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...     text_名詞-固有名詞-一般
# 11   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...     text_名詞-固有名詞-一般
# 12   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             、_記号-読点
# 13   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...             、_記号-読点
# 14      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される             、_記号-読点
# 15   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             、_記号-読点
# 16   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         が_助詞-格助詞-一般
# 17      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される         が_助詞-格助詞-一般
# 18   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            する_動詞-自立
# 19   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...            する_動詞-自立
# 20      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される            する_動詞-自立
# 21   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            する_動詞-自立
# 22   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...           て_助詞-接続助詞
# 23   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...           て_助詞-接続助詞
# 24   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         で_助詞-格助詞-一般
# 25   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...         で_助詞-格助詞-一般
# 26   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         で_助詞-格助詞-一般
# 27   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...           など_助詞-副助詞
# 28      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           など_助詞-副助詞
# 29   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            の_助詞-連体化
# ..                                                 ...                 ...
# 75   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...          型_名詞-接尾-一般
# 76   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...      文字列_名詞-固有名詞-一般
# 77   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...      文字列_名詞-固有名詞-一般
# 78   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...          群_名詞-接尾-一般
# 79      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される        t_名詞-固有名詞-組織
# 80   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...        t_名詞-固有名詞-組織
# 81      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           と_助詞-並立助詞
# 82      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           区切り_名詞-一般
# 83      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される             間_名詞-一般
# 84   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            ')_記号-一般
# 85   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           ('\_記号-一般
# 86   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         split_名詞-一般
# 87   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...    split_名詞-固有名詞-組織
# 88   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...       wakatid_名詞-一般
# 89   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             。_記号-句点
# 90   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            「\_記号-一般
# 91   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           が_助詞-接続助詞
# 92   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              たい_助動詞
# 93   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...      ため_名詞-非自立-副詞可能
# 94   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...               だ_助動詞
# 95   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           できる_動詞-自立
# 96   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              ない_助動詞
# 97   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             よって_接続詞
# 98   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         を_助詞-格助詞-一般
# 99   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...          使用_名詞-サ変接続
# 100  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            文字_名詞-一般
# 101  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              次に_接続詞
# 102  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            省く_動詞-自立
# 103  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...        邪魔_名詞-形容動詞語幹
# 104  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            関数_名詞-一般
#
#      count  word_count        tf  word_include_text_count
# 0        1          26  0.038462                        1
# 1        1          26  0.038462                        1
# 2        1          26  0.038462                        1
# 3        1          26  0.038462                        1
# 4        1          26  0.038462                        1
# 5        1          26  0.038462                        2
# 6        1          30  0.033333                        2
# 7        1          26  0.038462                        2
# 8        1          41  0.024390                        2
# 9        1          26  0.038462                        1
# 10       1          26  0.038462                        2
# 11       1          41  0.024390                        2
# 12       1          26  0.038462                        4
# 13       1          30  0.033333                        4
# 14       2          33  0.060606                        4
# 15       1          41  0.024390                        4
# 16       1          26  0.038462                        2
# 17       2          33  0.060606                        2
# 18       2          26  0.076923                        4
# 19       2          30  0.066667                        4
# 20       2          33  0.060606                        4
# 21       1          41  0.024390                        4
# 22       1          26  0.038462                        2
# 23       1          30  0.033333                        2
# 24       2          26  0.076923                        3
# 25       2          30  0.066667                        3
# 26       1          41  0.024390                        3
# 27       1          26  0.038462                        2
# 28       1          33  0.030303                        2
# 29       1          26  0.038462                        4
# ..     ...         ...       ...                      ...
# 75       2          41  0.048780                        2
# 76       1          30  0.033333                        2
# 77       1          41  0.024390                        2
# 78       1          30  0.033333                        1
# 79       1          33  0.030303                        2
# 80       2          41  0.048780                        2
# 81       1          33  0.030303                        1
# 82       1          33  0.030303                        1
# 83       1          33  0.030303                        1
# 84       1          41  0.024390                        1
# 85       1          41  0.024390                        1
# 86       1          41  0.024390                        1
# 87       1          41  0.024390                        1
# 88       1          41  0.024390                        1
# 89       1          41  0.024390                        1
# 90       1          41  0.024390                        1
# 91       1          41  0.024390                        1
# 92       2          41  0.048780                        1
# 93       1          41  0.024390                        1
# 94       1          41  0.024390                        1
# 95       1          41  0.024390                        1
# 96       2          41  0.048780                        1
# 97       1          41  0.024390                        1
# 98       3          41  0.073171                        1
# 99       2          41  0.048780                        1
# 100      1          41  0.024390                        1
# 101      1          41  0.024390                        1
# 102      1          41  0.024390                        1
# 103      1          41  0.024390                        1
# 104      1          41  0.024390                        1
#
# [105 rows x 6 columns]

# %%
idf_merge_df.isnull().any()
# Out:
# 内容                         False
# original_type              False
# count                      False
# word_count                 False
# tf                         False
# word_include_text_count    False
# dtype: bool

# %%
# dfの分子（全文書数）を格納する新規カラムを追加
idf_merge_df['all_text_count'] = len(contents_word_cnt_df['内容'].value_counts())
idf_merge_df
# Out:
#                                                     内容       original_type  \
# 0    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             (_記号-一般
# 1    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             )_記号-一般
# 2    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             ._記号-一般
# 3    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...              1_名詞-数
# 4    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...  NEologd_名詞-固有名詞-一般
# 5    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...    Parse_名詞-固有名詞-一般
# 6    まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...    Parse_名詞-固有名詞-一般
# 7    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             __記号-一般
# 8    次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             __記号-一般
# 9    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...   tagger_名詞-固有名詞-一般
# 10   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...     text_名詞-固有名詞-一般
# 11   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...     text_名詞-固有名詞-一般
# 12   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             、_記号-読点
# 13   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...             、_記号-読点
# 14      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される             、_記号-読点
# 15   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             、_記号-読点
# 16   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         が_助詞-格助詞-一般
# 17      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される         が_助詞-格助詞-一般
# 18   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            する_動詞-自立
# 19   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...            する_動詞-自立
# 20      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される            する_動詞-自立
# 21   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            する_動詞-自立
# 22   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...           て_助詞-接続助詞
# 23   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...           て_助詞-接続助詞
# 24   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         で_助詞-格助詞-一般
# 25   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...         で_助詞-格助詞-一般
# 26   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         で_助詞-格助詞-一般
# 27   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...           など_助詞-副助詞
# 28      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           など_助詞-副助詞
# 29   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            の_助詞-連体化
# ..                                                 ...                 ...
# 75   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...          型_名詞-接尾-一般
# 76   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...      文字列_名詞-固有名詞-一般
# 77   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...      文字列_名詞-固有名詞-一般
# 78   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...          群_名詞-接尾-一般
# 79      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される        t_名詞-固有名詞-組織
# 80   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...        t_名詞-固有名詞-組織
# 81      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           と_助詞-並立助詞
# 82      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           区切り_名詞-一般
# 83      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される             間_名詞-一般
# 84   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            ')_記号-一般
# 85   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           ('\_記号-一般
# 86   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         split_名詞-一般
# 87   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...    split_名詞-固有名詞-組織
# 88   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...       wakatid_名詞-一般
# 89   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             。_記号-句点
# 90   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            「\_記号-一般
# 91   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           が_助詞-接続助詞
# 92   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              たい_助動詞
# 93   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...      ため_名詞-非自立-副詞可能
# 94   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...               だ_助動詞
# 95   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           できる_動詞-自立
# 96   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              ない_助動詞
# 97   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             よって_接続詞
# 98   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         を_助詞-格助詞-一般
# 99   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...          使用_名詞-サ変接続
# 100  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            文字_名詞-一般
# 101  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              次に_接続詞
# 102  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            省く_動詞-自立
# 103  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...        邪魔_名詞-形容動詞語幹
# 104  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            関数_名詞-一般
#
#      count  word_count        tf  word_include_text_count  all_text_count
# 0        1          26  0.038462                        1               4
# 1        1          26  0.038462                        1               4
# 2        1          26  0.038462                        1               4
# 3        1          26  0.038462                        1               4
# 4        1          26  0.038462                        1               4
# 5        1          26  0.038462                        2               4
# 6        1          30  0.033333                        2               4
# 7        1          26  0.038462                        2               4
# 8        1          41  0.024390                        2               4
# 9        1          26  0.038462                        1               4
# 10       1          26  0.038462                        2               4
# 11       1          41  0.024390                        2               4
# 12       1          26  0.038462                        4               4
# 13       1          30  0.033333                        4               4
# 14       2          33  0.060606                        4               4
# 15       1          41  0.024390                        4               4
# 16       1          26  0.038462                        2               4
# 17       2          33  0.060606                        2               4
# 18       2          26  0.076923                        4               4
# 19       2          30  0.066667                        4               4
# 20       2          33  0.060606                        4               4
# 21       1          41  0.024390                        4               4
# 22       1          26  0.038462                        2               4
# 23       1          30  0.033333                        2               4
# 24       2          26  0.076923                        3               4
# 25       2          30  0.066667                        3               4
# 26       1          41  0.024390                        3               4
# 27       1          26  0.038462                        2               4
# 28       1          33  0.030303                        2               4
# 29       1          26  0.038462                        4               4
# ..     ...         ...       ...                      ...             ...
# 75       2          41  0.048780                        2               4
# 76       1          30  0.033333                        2               4
# 77       1          41  0.024390                        2               4
# 78       1          30  0.033333                        1               4
# 79       1          33  0.030303                        2               4
# 80       2          41  0.048780                        2               4
# 81       1          33  0.030303                        1               4
# 82       1          33  0.030303                        1               4
# 83       1          33  0.030303                        1               4
# 84       1          41  0.024390                        1               4
# 85       1          41  0.024390                        1               4
# 86       1          41  0.024390                        1               4
# 87       1          41  0.024390                        1               4
# 88       1          41  0.024390                        1               4
# 89       1          41  0.024390                        1               4
# 90       1          41  0.024390                        1               4
# 91       1          41  0.024390                        1               4
# 92       2          41  0.048780                        1               4
# 93       1          41  0.024390                        1               4
# 94       1          41  0.024390                        1               4
# 95       1          41  0.024390                        1               4
# 96       2          41  0.048780                        1               4
# 97       1          41  0.024390                        1               4
# 98       3          41  0.073171                        1               4
# 99       2          41  0.048780                        1               4
# 100      1          41  0.024390                        1               4
# 101      1          41  0.024390                        1               4
# 102      1          41  0.024390                        1               4
# 103      1          41  0.024390                        1               4
# 104      1          41  0.024390                        1               4
#
# [105 rows x 7 columns]

# %%
# idfを算出
# データフレーム型にapply関数を使う際には、axis=1を忘れないように注意
import math
idf_merge_df['idf'] = idf_merge_df.progress_apply(lambda x: math.log(x['all_text_count'] / x['word_include_text_count']) + 1 , axis=1)
# Out:
# HBox(children=(IntProgress(value=0, description='progress: ', max=105), HTML(value='')))

# %%
idf_merge_df
# Out:
#                                                     内容       original_type  \
# 0    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             (_記号-一般
# 1    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             )_記号-一般
# 2    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             ._記号-一般
# 3    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...              1_名詞-数
# 4    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...  NEologd_名詞-固有名詞-一般
# 5    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...    Parse_名詞-固有名詞-一般
# 6    まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...    Parse_名詞-固有名詞-一般
# 7    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             __記号-一般
# 8    次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             __記号-一般
# 9    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...   tagger_名詞-固有名詞-一般
# 10   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...     text_名詞-固有名詞-一般
# 11   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...     text_名詞-固有名詞-一般
# 12   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             、_記号-読点
# 13   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...             、_記号-読点
# 14      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される             、_記号-読点
# 15   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             、_記号-読点
# 16   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         が_助詞-格助詞-一般
# 17      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される         が_助詞-格助詞-一般
# 18   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            する_動詞-自立
# 19   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...            する_動詞-自立
# 20      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される            する_動詞-自立
# 21   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            する_動詞-自立
# 22   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...           て_助詞-接続助詞
# 23   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...           て_助詞-接続助詞
# 24   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         で_助詞-格助詞-一般
# 25   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...         で_助詞-格助詞-一般
# 26   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         で_助詞-格助詞-一般
# 27   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...           など_助詞-副助詞
# 28      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           など_助詞-副助詞
# 29   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            の_助詞-連体化
# ..                                                 ...                 ...
# 75   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...          型_名詞-接尾-一般
# 76   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...      文字列_名詞-固有名詞-一般
# 77   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...      文字列_名詞-固有名詞-一般
# 78   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...          群_名詞-接尾-一般
# 79      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される        t_名詞-固有名詞-組織
# 80   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...        t_名詞-固有名詞-組織
# 81      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           と_助詞-並立助詞
# 82      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           区切り_名詞-一般
# 83      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される             間_名詞-一般
# 84   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            ')_記号-一般
# 85   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           ('\_記号-一般
# 86   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         split_名詞-一般
# 87   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...    split_名詞-固有名詞-組織
# 88   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...       wakatid_名詞-一般
# 89   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             。_記号-句点
# 90   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            「\_記号-一般
# 91   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           が_助詞-接続助詞
# 92   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              たい_助動詞
# 93   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...      ため_名詞-非自立-副詞可能
# 94   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...               だ_助動詞
# 95   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           できる_動詞-自立
# 96   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              ない_助動詞
# 97   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             よって_接続詞
# 98   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         を_助詞-格助詞-一般
# 99   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...          使用_名詞-サ変接続
# 100  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            文字_名詞-一般
# 101  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              次に_接続詞
# 102  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            省く_動詞-自立
# 103  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...        邪魔_名詞-形容動詞語幹
# 104  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            関数_名詞-一般
#
#      count  word_count        tf  word_include_text_count  all_text_count  \
# 0        1          26  0.038462                        1               4
# 1        1          26  0.038462                        1               4
# 2        1          26  0.038462                        1               4
# 3        1          26  0.038462                        1               4
# 4        1          26  0.038462                        1               4
# 5        1          26  0.038462                        2               4
# 6        1          30  0.033333                        2               4
# 7        1          26  0.038462                        2               4
# 8        1          41  0.024390                        2               4
# 9        1          26  0.038462                        1               4
# 10       1          26  0.038462                        2               4
# 11       1          41  0.024390                        2               4
# 12       1          26  0.038462                        4               4
# 13       1          30  0.033333                        4               4
# 14       2          33  0.060606                        4               4
# 15       1          41  0.024390                        4               4
# 16       1          26  0.038462                        2               4
# 17       2          33  0.060606                        2               4
# 18       2          26  0.076923                        4               4
# 19       2          30  0.066667                        4               4
# 20       2          33  0.060606                        4               4
# 21       1          41  0.024390                        4               4
# 22       1          26  0.038462                        2               4
# 23       1          30  0.033333                        2               4
# 24       2          26  0.076923                        3               4
# 25       2          30  0.066667                        3               4
# 26       1          41  0.024390                        3               4
# 27       1          26  0.038462                        2               4
# 28       1          33  0.030303                        2               4
# 29       1          26  0.038462                        4               4
# ..     ...         ...       ...                      ...             ...
# 75       2          41  0.048780                        2               4
# 76       1          30  0.033333                        2               4
# 77       1          41  0.024390                        2               4
# 78       1          30  0.033333                        1               4
# 79       1          33  0.030303                        2               4
# 80       2          41  0.048780                        2               4
# 81       1          33  0.030303                        1               4
# 82       1          33  0.030303                        1               4
# 83       1          33  0.030303                        1               4
# 84       1          41  0.024390                        1               4
# 85       1          41  0.024390                        1               4
# 86       1          41  0.024390                        1               4
# 87       1          41  0.024390                        1               4
# 88       1          41  0.024390                        1               4
# 89       1          41  0.024390                        1               4
# 90       1          41  0.024390                        1               4
# 91       1          41  0.024390                        1               4
# 92       2          41  0.048780                        1               4
# 93       1          41  0.024390                        1               4
# 94       1          41  0.024390                        1               4
# 95       1          41  0.024390                        1               4
# 96       2          41  0.048780                        1               4
# 97       1          41  0.024390                        1               4
# 98       3          41  0.073171                        1               4
# 99       2          41  0.048780                        1               4
# 100      1          41  0.024390                        1               4
# 101      1          41  0.024390                        1               4
# 102      1          41  0.024390                        1               4
# 103      1          41  0.024390                        1               4
# 104      1          41  0.024390                        1               4
#
#           idf
# 0    2.386294
# 1    2.386294
# 2    2.386294
# 3    2.386294
# 4    2.386294
# 5    1.693147
# 6    1.693147
# 7    1.693147
# 8    1.693147
# 9    2.386294
# 10   1.693147
# 11   1.693147
# 12   1.000000
# 13   1.000000
# 14   1.000000
# 15   1.000000
# 16   1.693147
# 17   1.693147
# 18   1.000000
# 19   1.000000
# 20   1.000000
# 21   1.000000
# 22   1.693147
# 23   1.693147
# 24   1.287682
# 25   1.287682
# 26   1.287682
# 27   1.693147
# 28   1.693147
# 29   1.000000
# ..        ...
# 75   1.693147
# 76   1.693147
# 77   1.693147
# 78   2.386294
# 79   1.693147
# 80   1.693147
# 81   2.386294
# 82   2.386294
# 83   2.386294
# 84   2.386294
# 85   2.386294
# 86   2.386294
# 87   2.386294
# 88   2.386294
# 89   2.386294
# 90   2.386294
# 91   2.386294
# 92   2.386294
# 93   2.386294
# 94   2.386294
# 95   2.386294
# 96   2.386294
# 97   2.386294
# 98   2.386294
# 99   2.386294
# 100  2.386294
# 101  2.386294
# 102  2.386294
# 103  2.386294
# 104  2.386294
#
# [105 rows x 8 columns]

# %% [markdown]
# ## TFIDF値を算出し新規カラムを作成

# %%
idf_merge_df['tf_idf'] = idf_merge_df['tf'] * idf_merge_df['idf']
idf_merge_df
# Out:
#                                                     内容       original_type  \
# 0    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             (_記号-一般
# 1    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             )_記号-一般
# 2    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             ._記号-一般
# 3    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...              1_名詞-数
# 4    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...  NEologd_名詞-固有名詞-一般
# 5    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...    Parse_名詞-固有名詞-一般
# 6    まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...    Parse_名詞-固有名詞-一般
# 7    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             __記号-一般
# 8    次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             __記号-一般
# 9    neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...   tagger_名詞-固有名詞-一般
# 10   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...     text_名詞-固有名詞-一般
# 11   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...     text_名詞-固有名詞-一般
# 12   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             、_記号-読点
# 13   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...             、_記号-読点
# 14      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される             、_記号-読点
# 15   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             、_記号-読点
# 16   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         が_助詞-格助詞-一般
# 17      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される         が_助詞-格助詞-一般
# 18   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            する_動詞-自立
# 19   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...            する_動詞-自立
# 20      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される            する_動詞-自立
# 21   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            する_動詞-自立
# 22   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...           て_助詞-接続助詞
# 23   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...           て_助詞-接続助詞
# 24   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...         で_助詞-格助詞-一般
# 25   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...         で_助詞-格助詞-一般
# 26   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         で_助詞-格助詞-一般
# 27   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...           など_助詞-副助詞
# 28      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           など_助詞-副助詞
# 29   neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...            の_助詞-連体化
# ..                                                 ...                 ...
# 75   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...          型_名詞-接尾-一般
# 76   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...      文字列_名詞-固有名詞-一般
# 77   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...      文字列_名詞-固有名詞-一般
# 78   まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、...          群_名詞-接尾-一般
# 79      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される        t_名詞-固有名詞-組織
# 80   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...        t_名詞-固有名詞-組織
# 81      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           と_助詞-並立助詞
# 82      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           区切り_名詞-一般
# 83      原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される             間_名詞-一般
# 84   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            ')_記号-一般
# 85   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           ('\_記号-一般
# 86   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         split_名詞-一般
# 87   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...    split_名詞-固有名詞-組織
# 88   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...       wakatid_名詞-一般
# 89   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             。_記号-句点
# 90   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            「\_記号-一般
# 91   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           が_助詞-接続助詞
# 92   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              たい_助動詞
# 93   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...      ため_名詞-非自立-副詞可能
# 94   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...               だ_助動詞
# 95   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...           できる_動詞-自立
# 96   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              ない_助動詞
# 97   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...             よって_接続詞
# 98   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...         を_助詞-格助詞-一般
# 99   次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...          使用_名詞-サ変接続
# 100  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            文字_名詞-一般
# 101  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...              次に_接続詞
# 102  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            省く_動詞-自立
# 103  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...        邪魔_名詞-形容動詞語幹
# 104  次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid...            関数_名詞-一般
#
#      count  word_count        tf  word_include_text_count  all_text_count  \
# 0        1          26  0.038462                        1               4
# 1        1          26  0.038462                        1               4
# 2        1          26  0.038462                        1               4
# 3        1          26  0.038462                        1               4
# 4        1          26  0.038462                        1               4
# 5        1          26  0.038462                        2               4
# 6        1          30  0.033333                        2               4
# 7        1          26  0.038462                        2               4
# 8        1          41  0.024390                        2               4
# 9        1          26  0.038462                        1               4
# 10       1          26  0.038462                        2               4
# 11       1          41  0.024390                        2               4
# 12       1          26  0.038462                        4               4
# 13       1          30  0.033333                        4               4
# 14       2          33  0.060606                        4               4
# 15       1          41  0.024390                        4               4
# 16       1          26  0.038462                        2               4
# 17       2          33  0.060606                        2               4
# 18       2          26  0.076923                        4               4
# 19       2          30  0.066667                        4               4
# 20       2          33  0.060606                        4               4
# 21       1          41  0.024390                        4               4
# 22       1          26  0.038462                        2               4
# 23       1          30  0.033333                        2               4
# 24       2          26  0.076923                        3               4
# 25       2          30  0.066667                        3               4
# 26       1          41  0.024390                        3               4
# 27       1          26  0.038462                        2               4
# 28       1          33  0.030303                        2               4
# 29       1          26  0.038462                        4               4
# ..     ...         ...       ...                      ...             ...
# 75       2          41  0.048780                        2               4
# 76       1          30  0.033333                        2               4
# 77       1          41  0.024390                        2               4
# 78       1          30  0.033333                        1               4
# 79       1          33  0.030303                        2               4
# 80       2          41  0.048780                        2               4
# 81       1          33  0.030303                        1               4
# 82       1          33  0.030303                        1               4
# 83       1          33  0.030303                        1               4
# 84       1          41  0.024390                        1               4
# 85       1          41  0.024390                        1               4
# 86       1          41  0.024390                        1               4
# 87       1          41  0.024390                        1               4
# 88       1          41  0.024390                        1               4
# 89       1          41  0.024390                        1               4
# 90       1          41  0.024390                        1               4
# 91       1          41  0.024390                        1               4
# 92       2          41  0.048780                        1               4
# 93       1          41  0.024390                        1               4
# 94       1          41  0.024390                        1               4
# 95       1          41  0.024390                        1               4
# 96       2          41  0.048780                        1               4
# 97       1          41  0.024390                        1               4
# 98       3          41  0.073171                        1               4
# 99       2          41  0.048780                        1               4
# 100      1          41  0.024390                        1               4
# 101      1          41  0.024390                        1               4
# 102      1          41  0.024390                        1               4
# 103      1          41  0.024390                        1               4
# 104      1          41  0.024390                        1               4
#
#           idf    tf_idf
# 0    2.386294  0.091781
# 1    2.386294  0.091781
# 2    2.386294  0.091781
# 3    2.386294  0.091781
# 4    2.386294  0.091781
# 5    1.693147  0.065121
# 6    1.693147  0.056438
# 7    1.693147  0.065121
# 8    1.693147  0.041296
# 9    2.386294  0.091781
# 10   1.693147  0.065121
# 11   1.693147  0.041296
# 12   1.000000  0.038462
# 13   1.000000  0.033333
# 14   1.000000  0.060606
# 15   1.000000  0.024390
# 16   1.693147  0.065121
# 17   1.693147  0.102615
# 18   1.000000  0.076923
# 19   1.000000  0.066667
# 20   1.000000  0.060606
# 21   1.000000  0.024390
# 22   1.693147  0.065121
# 23   1.693147  0.056438
# 24   1.287682  0.099052
# 25   1.287682  0.085845
# 26   1.287682  0.031407
# 27   1.693147  0.065121
# 28   1.693147  0.051307
# 29   1.000000  0.038462
# ..        ...       ...
# 75   1.693147  0.082593
# 76   1.693147  0.056438
# 77   1.693147  0.041296
# 78   2.386294  0.079543
# 79   1.693147  0.051307
# 80   1.693147  0.082593
# 81   2.386294  0.072312
# 82   2.386294  0.072312
# 83   2.386294  0.072312
# 84   2.386294  0.058202
# 85   2.386294  0.058202
# 86   2.386294  0.058202
# 87   2.386294  0.058202
# 88   2.386294  0.058202
# 89   2.386294  0.058202
# 90   2.386294  0.058202
# 91   2.386294  0.058202
# 92   2.386294  0.116405
# 93   2.386294  0.058202
# 94   2.386294  0.058202
# 95   2.386294  0.058202
# 96   2.386294  0.116405
# 97   2.386294  0.058202
# 98   2.386294  0.174607
# 99   2.386294  0.116405
# 100  2.386294  0.058202
# 101  2.386294  0.058202
# 102  2.386294  0.058202
# 103  2.386294  0.058202
# 104  2.386294  0.058202
#
# [105 rows x 9 columns]

# %% [markdown]
# ## テキスト内容×単語のデータフレーム を作成

# %%
idf_merge_df2 = idf_merge_df[['内容', 'original_type', 'tf_idf']]
idf_merge_df2.head()
# Out:
#                                                   内容       original_type  \
# 0  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             (_記号-一般
# 1  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             )_記号-一般
# 2  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...             ._記号-一般
# 3  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...              1_名詞-数
# 4  neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して...  NEologd_名詞-固有名詞-一般
#
#      tf_idf
# 0  0.091781
# 1  0.091781
# 2  0.091781
# 3  0.091781
# 4  0.091781

# %%
model_df = pd.pivot_table(idf_merge_df2, index='内容', columns='original_type')
# nanは0に変換する
model_df = model_df.fillna(0)
model_df
# Out:
#                                                       tf_idf            \
# original_type                                       ')_記号-一般 ('\_記号-一般
# 内容
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...  0.000000  0.000000
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...  0.000000  0.000000
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される      0.000000  0.000000
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...  0.058202  0.058202
#
#                                                                             \
# original_type                                      ()_名詞-固有名詞-一般   (_記号-一般
# 内容
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...      0.000000  0.091781
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...      0.079543  0.000000
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される          0.000000  0.000000
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...      0.000000  0.000000
#
#                                                                         \
# original_type                                        )_記号-一般   ._記号-一般
# 内容
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...  0.091781  0.091781
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...  0.000000  0.000000
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される      0.000000  0.000000
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...  0.000000  0.000000
#
#                                                                         \
# original_type                                         1_名詞-数  1つ_名詞-一般
# 内容
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...  0.091781  0.000000
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...  0.000000  0.079543
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される      0.000000  0.000000
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...  0.000000  0.000000
#
#                                                                        \
# original_type                                      NEologd_名詞-固有名詞-一般
# 内容
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...           0.091781
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...           0.000000
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される               0.000000
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...           0.000000
#
#                                                                        ...     \
# original_type                                      Parse_名詞-固有名詞-一般    ...
# 内容                                                                     ...
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...         0.065121    ...
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...         0.056438    ...
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される             0.000000    ...
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...         0.000000    ...
#
#                                                                              \
# original_type                                      文字列_名詞-固有名詞-一般    次に_接続詞
# 内容
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...       0.000000  0.000000
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...       0.056438  0.000000
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される           0.000000  0.000000
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...       0.041296  0.058202
#
#                                                                          \
# original_type                                       省く_動詞-自立 群_名詞-接尾-一般
# 内容
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...  0.000000   0.000000
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...  0.000000   0.079543
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される      0.000000   0.000000
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...  0.058202   0.000000
#
#                                                                            \
# original_type                                      行_名詞-接尾-助数詞 表示_名詞-サ変接続
# 内容
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...    0.091781   0.065121
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...    0.000000   0.000000
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される        0.000000   0.051307
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...    0.000000   0.000000
#
#                                                                             \
# original_type                                      連続_名詞-サ変接続 邪魔_名詞-形容動詞語幹
# 内容
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...   0.091781     0.000000
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...   0.000000     0.000000
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される       0.000000     0.000000
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...   0.000000     0.058202
#
#
# original_type                                        間_名詞-一般  関数_名詞-一般
# 内容
# neologd_tagger.parse(text)で各単語の原形、品詞などが1行で連続して表...  0.000000  0.000000
# まずはparse()で分かち書きした単語群は1つの文字列型になっているので「\n」で区切り、リ...  0.000000  0.000000
# 原形、品詞などの間には「\t」が、分かち書きされた単語と単語の区切りには「\n」が表示される      0.072312  0.000000
# 次に邪魔な文字「\t」を省きたい。よって、split('\t')を使用したいがwakatid_...  0.000000  0.058202
#
# [4 rows x 68 columns]
